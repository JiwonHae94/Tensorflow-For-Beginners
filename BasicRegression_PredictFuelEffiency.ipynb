# %% [markdown]
# <a href="https://colab.research.google.com/github/JiwonHae94/Tensorflow/blob/develop/BasicRegression_PredictFuelEffiency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
